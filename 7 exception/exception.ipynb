# %%
try:
    num=int(input("Enter a number"))
    result=200/num
except ZeroDivisionError as zr:
    print(zr)
except ValueError as vl:
    print(vl)
except Exception as ex:
    print(ex)
    print("Parent Exception")
else:                   ##if no error occures then only else is executed
    
    print("The result is : ",result)
finally:                ## finally is executed even in case if error occures
    print("Execution is completed")
# Out:
# invalid literal for int() with base 10: 'xkj'
# Execution is completed

# %%
try:
    
    file=open("example.txt",'r')
    content=file.read()
    print(content)
except FileNotFoundError as fn:
    print("File does not exist")
except Exception:
    print("An exception occured")
finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print("File is closed")
# Out:
# Hello World!
# File is closed
