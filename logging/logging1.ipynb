# %%
import logging

# %%
import logging
###configurethe basic logging setting 
logging.basicConfig(level=logging.DEBUG)


# log messages

logging.debug("This is a debug message ")
logging.info("This is a info message ")
logging.warning("This is a warning message ")
logging.critical("This is a critical message ")
logging.error("This is a error message ")
# Out:
# DEBUG:root:This is a debug message
# INFO:root:This is a info message
# WARNING:root:This is a warning message
# CRITICAL:root:This is a critical message
# ERROR:root:This is a error message

# %%
logging.debug("This is a debug message ")
logging.info("This is a info message ")
logging.warning("This is a warning message ")
logging.critical("This is a critical message ")
logging.error("This is a error message ")
# Out:
# 2025-10-20 19:48:42,720-root-DEBUG-This is a debug message
# 2025-10-20 19:48:42,721-root-INFO-This is a info message
# 2025-10-20 19:48:42,722-root-WARNING-This is a warning message
# 2025-10-20 19:48:42,722-root-CRITICAL-This is a critical message
# 2025-10-20 19:48:42,723-root-ERROR-This is a error message

# %%
#### configuring logging

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %h:%M:%S'
)


logging.debug("This is a debug message ")
logging.info("This is a info message ")
logging.warning("This is a warning message ")
logging.critical("This is a critical message ")
logging.error("This is a error message ")
# Out:
# 2025-10-20 19:48:32,329-root-DEBUG-This is a debug message
# 2025-10-20 19:48:32,329-root-INFO-This is a info message
# 2025-10-20 19:48:32,331-root-WARNING-This is a warning message
# 2025-10-20 19:48:32,332-root-CRITICAL-This is a critical message
# 2025-10-20 19:48:32,336-root-ERROR-This is a error message

# %%
#### configuring logging
import logging
logging.basicConfig(
    filename='app.log',
    filemode='w',
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)


logging.debug("This is a debug message ")
logging.info("This is a info message ")
logging.warning("This is a warning message ")
logging.critical("This is a critical message ")
logging.error("This is a error message ")
