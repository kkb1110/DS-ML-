# %% [markdown]
# You can use multiple loggers for different different module or other purposes

# %%
import logging
### create a logger for module1
logger1=logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

### create second logger for module2
logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
### log messages with different loggers

logger1.debug("This is a debug message")
logger1.debug("This is second debug message")
logger1.warning("This is a warning message")
logger2.warning("This is a warning message")
# Out:
# 2025-10-20 20:35:24-module1-DEBUG-This is a debug message
# 2025-10-20 20:35:24-module1-DEBUG-This is second debug message
# 2025-10-20 20:35:24-module1-WARNING-This is a warning message
# 2025-10-20 20:35:24-module2-WARNING-This is a warning message
