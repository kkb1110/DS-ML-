# %%
import sys

# %%
v=45
print(sys.getrefcount(v
))
# Out:
# 4294967295

# %%
b=v
print(b)
print(sys.getrefcount(b))
# Out:
# 45
# 4294967295

# %% [markdown]
# #### Garbage collecter

# %%
import gc
## to enable garbage collecter
gc.enable()

# %%
## to disable garbage collecter
gc.disable()

# %%
gc.collect()
# Out:
# 0

# %%
### get garbagge collection stats
print(gc.get_stats())
# Out:
# [{'collections': 195, 'collected': 1648, 'uncollectable': 0}, {'collections': 17, 'collected': 600, 'uncollectable': 0}, {'collections': 3, 'collected': 3035, 'uncollectable': 0}]

# %%
### get unreachable objects
print(gc.garbage)
# Out:
# []
