# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import fetch_california_housing

# %%
california=fetch_california_housing()

# %%
california.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
dataset=pd.DataFrame(california.data,columns=california.feature_names
                     )
dataset.head
# Out:
# <bound method NDFrame.head of        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]>

# %%
dataset['Price']=california.target
dataset
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# 4        -122.25  3.422
# ...          ...    ...
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894
#
# [20640 rows x 9 columns]

# %%
dataset.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# Price         0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
dataset.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         Price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# min        0.692308     32.540000   -124.350000      0.149990
# 25%        2.429741     33.930000   -121.800000      1.196000
# 50%        2.818116     34.260000   -118.490000      1.797000
# 75%        3.282261     37.710000   -118.010000      2.647250
# max     1243.333333     41.950000   -114.310000      5.000010

# %%
sns.heatmap(dataset.corr(),annot=True)
# Out:
# <Axes: >

# %%
X=dataset.drop('Price',axis=1) ## dataset.iloc[:,:-1]
y=dataset['Price']

# %%
X
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)

# %%
X_train.shape
# Out:
# (14448, 8)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# ## Model tarining

# %%
from sklearn.linear_model import LinearRegression
regressionModel=LinearRegression()
regressionModel.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regressionModel.coef_
# Out:
# array([ 0.83329476,  0.12211856, -0.28024737,  0.33652609,  0.00148665,
#        -0.02868206, -0.92659537, -0.89282551])

# %%
y_pred=regressionModel.predict(X_test)
y_pred
# Out:
# array([3.00818422, 2.58387257, 2.35282009, ..., 1.78941655, 2.58881603,
#        1.44575813], shape=(6192,))

# %%
plt.scatter(x=y_test,y=y_pred,c='red')

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2=r2_score(y_test,y_pred)
print("R2 Score:",r2)
mse=mean_squared_error(y_test,y_pred)
print("Mean Squared Error:",mse)
mae=mean_absolute_error(y_test,y_pred)
print("Mean Absolute Error:",mae)
rmse=np.sqrt(mse)
print("Root Mean Squared Error:",rmse)
## adjusted r squared
adjusted_r2=1-(1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
print("Adjusted R2 Score:", adjusted_r2)
# Out:
# R2 Score: 0.5913048824900671
# Mean Squared Error: 0.5540440300082569
# Mean Absolute Error: 0.5370779294017782
# Root Mean Squared Error: 0.7443413397146882
# Adjusted R2 Score: 0.5907760840200559

# %%
residuals=y_test-y_pred
print(residuals)
sns.displot(residuals, kind="kde")  ## should be normally distributed
# Out:
# 20303   -1.334184
# 16966    0.957127
# 10623   -0.750820
# 6146    -0.306735
# 2208    -0.666426
#            ...
# 520     -0.127491
# 6833     0.697401
# 9559    -0.488417
# 14878   -1.084816
# 2497    -0.320758
# Name: Price, Length: 6192, dtype: float64

# %%
plt.scatter(y_pred,residuals)

# %% [markdown]
# ## Pickling

# %%
import pickle
pickle.dump(regressionModel,open('regressor.pkl','wb'))

# %%
model=pickle.load(open('regressor.pkl','rb'))

# %%
model.predict(X_test)
# Out:
# array([3.00818422, 2.58387257, 2.35282009, ..., 1.78941655, 2.58881603,
#        1.44575813], shape=(6192,))

# %%
from sklearn.linear_model import ElasticNet
esnetModel=ElasticNet()
esnetModel.fit(X_train,y_train)
# Out:
# ElasticNet()

# %%
y_pred2=esnetModel.predict(X_test)

# %%
r2=r2_score(y_test,y_pred2)
print("R2 Score:",r2)
mse=mean_squared_error(y_test,y_pred2)
print("Mean Squared Error:",mse)
mae=mean_absolute_error(y_test,y_pred2)
print("Mean Absolute Error:",mae)
rmse=np.sqrt(mse)
print("Root Mean Squared Error:",rmse)
## adjusted r squared
adjusted_r2=1-(1-r2)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
print("Adjusted R2 Score:", adjusted_r2)
# Out:
# R2 Score: 0.20450147935594376
# Mean Squared Error: 1.0784107452238594
# Mean Absolute Error: 0.8214276389355799
# Root Mean Squared Error: 1.0384655724788663
# Adjusted R2 Score: 0.20347220745473837
