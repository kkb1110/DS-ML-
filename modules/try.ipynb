# %%
import random
print(random.randint(3,200))
# Out:
# 11

# %%
print(random.choice(["apple","banana","cherry","guava"]))
# Out:
# apple

# %%
import os 
print(os.getcwd())
# Out:
# c:\Users\krish\OneDrive\Desktop\DS&ML\basics\modules

# %%
print(os.mkdir("new_directory"))
# Out:
# None

# %%
import shutil
shutil.copyfile("source.txt","destination.txt")
# Out:
# 'destination.txt'
